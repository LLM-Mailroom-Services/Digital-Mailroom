# %% [markdown]
# # The-Mailroom demos
#
# Still gallery + screen recordings of every live surface. These are captures
# of the pixel console, hosted Observatory, and TUI against the same display
# API — **Langfuse remains the sole display source**. Nothing here is canned
# data served to the UI; the stills and recordings are documentation of the
# live desks.
#
# | Asset | Path |
# |---|---|
# | This notebook | `docs/demos/The-Mailroom-Demos.ipynb` |
# | **HF Space live Observatory** (~102s) | [`hf-space-observatory-live-walkthrough.mp4`](hf-space-observatory-live-walkthrough.mp4) |
# | **v0.3.0 pixel desks** (~42s) | [`v030-pixel-desks-review-resolve.mp4`](v030-pixel-desks-review-resolve.mp4) |
# | **v0.3.0 Observatory** (~52s) | [`v030-observatory-review-resolve.mp4`](v030-observatory-review-resolve.mp4) |
# | Desk walkthrough (~56s) | [`tui-server-observatory-desk-walkthrough.mp4`](tui-server-observatory-desk-walkthrough.mp4) |
# | **Pilot run — envelopes moving** (~25s) | [`pilot-run-documents-through-pipeline.mp4`](pilot-run-documents-through-pipeline.mp4) |
# | Stills | [`docs/screenshots/`](../screenshots/) |
# | Markdown twin | [`docs/demos.md`](../demos.md) · wiki [`Demos`](../../wiki/Demos.md) |
#
# On GitHub, click the `.mp4` to play it in the browser. Run this notebook
# locally (any Python 3 kernel with IPython) to play it inline.

# %% [markdown]
# ## Hugging Face Space — live Observatory (2026-08-30)
#
# Public Docker Space after #30: classification cards, headline strip, inbox
# setup hint, Export snapshot, then Review / History / Matters / Metrics / Debug.
# Langfuse is the display source. Producer knobs were unset.
#
# Live: https://lucius-morningstar-mailroom-observatory.hf.space/
#
# [![HF Space Observatory Pipeline](hf-space-observatory-poster.png)](hf-space-observatory-live-walkthrough.mp4)
#
# **File:** [`hf-space-observatory-live-walkthrough.mp4`](hf-space-observatory-live-walkthrough.mp4) (H.264, ~15 MB, 102 seconds).

# %%
from pathlib import Path

try:
    from IPython.display import Video, display, Markdown
except ImportError:
    Video = None

HERE = Path.cwd()
name = "hf-space-observatory-live-walkthrough.mp4"
candidates = [HERE / name, HERE / "docs" / "demos" / name]
video = next((p for p in candidates if p.exists()), None)
if video is None:
    raise FileNotFoundError(name)
if Video is not None:
    display(Markdown(f"Playing `{video}`"))
    display(Video(str(video), embed=False, width=900))
else:
    print("open", video)

# %% [markdown]
# ## v0.3.0 — pixel desks (hopper + REVIEW resolve)
#
# Full-screen recording of the pixel console against `scripts/demo_v030_cast.py`.
# FLOOR shows the INBOX hopper; REVIEW Approve posts `/api/review/resolve` and
# surfaces the honest 503 when `MAILROOM_PIPELINE_URL` is unset.
#
# [![v0.3.0 pixel REVIEW](v030-pixel-poster.png)](v030-pixel-desks-review-resolve.mp4)
#
# **File:** [`v030-pixel-desks-review-resolve.mp4`](v030-pixel-desks-review-resolve.mp4) (H.264, ~3.8 MB, 42 seconds).

# %%
from pathlib import Path

try:
    from IPython.display import Video, display, Markdown
except ImportError:
    Video = None

HERE = Path.cwd()
name = "v030-pixel-desks-review-resolve.mp4"
candidates = [HERE / name, HERE / "docs" / "demos" / name]
video = next((p for p in candidates if p.exists()), None)
if video is None:
    raise FileNotFoundError(name)
if Video is not None:
    display(Markdown(f"Playing `{video}`"))
    display(Video(str(video), embed=False, width=900))
else:
    print("open", video)

# %% [markdown]
# ## v0.3.0 — Observatory (Inbox tray + Review resolve)
#
# Pipeline Inbox tray, Review Approve / Reject / Requeue, inspect dialog,
# then History / Matters / Metrics / Debug.
#
# [![v0.3.0 Observatory Pipeline](v030-observatory-poster.png)](v030-observatory-review-resolve.mp4)
#
# **File:** [`v030-observatory-review-resolve.mp4`](v030-observatory-review-resolve.mp4) (H.264, ~8.1 MB, 52 seconds).

# %%
from pathlib import Path

try:
    from IPython.display import Video, display, Markdown
except ImportError:
    Video = None

HERE = Path.cwd()
name = "v030-observatory-review-resolve.mp4"
candidates = [HERE / name, HERE / "docs" / "demos" / name]
video = next((p for p in candidates if p.exists()), None)
if video is None:
    raise FileNotFoundError(name)
if Video is not None:
    display(Markdown(f"Playing `{video}`"))
    display(Video(str(video), embed=False, width=900))
else:
    print("open", video)

# %% [markdown]
# ## Desk walkthrough (PR recording)
#
# Pixel FLOOR → REVIEW → SESSIONS → HISTORY → METRICS → CONSOLE → inspector,
# then Observatory Pipeline → Review → History → Matters → Metrics → Debug.
#
# [![Walkthrough poster — click through to the video](walkthrough-poster.png)](tui-server-observatory-desk-walkthrough.mp4)
#
# **File:** [`tui-server-observatory-desk-walkthrough.mp4`](tui-server-observatory-desk-walkthrough.mp4) (H.264, ~5.5 MB, 56 seconds).

# %%
from pathlib import Path

try:
    from IPython.display import Video, display, Markdown
except ImportError:
    Video = None

HERE = Path.cwd()
candidates = [
    HERE / "tui-server-observatory-desk-walkthrough.mp4",
    HERE / "docs" / "demos" / "tui-server-observatory-desk-walkthrough.mp4",
]
video = next((p for p in candidates if p.exists()), None)
if video is None:
    raise FileNotFoundError(
        "walkthrough mp4 not found — open this notebook from docs/demos/ "
        "or the repo root"
    )
if Video is not None:
    display(Markdown(f"Playing `{video}`"))
    display(Video(str(video), embed=False, width=900))
else:
    print("open", video)

# %% [markdown]
# ## Pilot run — documents moving through the pipeline
#
# Five documents in matter `pilot-run-2026-08-25` enter at SORTER and slide
# the conveyor. The merger agreement peels onto REVIEW; a corporate record
# fails off the belt; the rest archive.
#
# [![Pilot run poster](pilot-run-poster.png)](pilot-run-documents-through-pipeline.mp4)
#
# **File:** [`pilot-run-documents-through-pipeline.mp4`](pilot-run-documents-through-pipeline.mp4) (H.264, ~2.9 MB, 25 seconds).
#
# Re-record: `PYTHONPATH=. python scripts/demo_pilot_run.py --port 8005`
# then open `http://127.0.0.1:8005/?api=`.

# %%
from pathlib import Path

try:
    from IPython.display import Video, display, Markdown
except ImportError:
    Video = None

HERE = Path.cwd()
name = "pilot-run-documents-through-pipeline.mp4"
candidates = [HERE / name, HERE / "docs" / "demos" / name]
video = next((p for p in candidates if p.exists()), None)
if video is None:
    raise FileNotFoundError(name)
if Video is not None:
    display(Markdown(f"Playing `{video}`"))
    display(Video(str(video), embed=False, width=900))
else:
    print("open", video)

# %% [markdown]
# ## Pixel-art console (`mailroom-web`)
#
# Seven stations on the conveyor, inspector, review siding, sessions, history
# with REPLAY, metrics, and the live console.

# %% [markdown]
# ![FLOOR — conveyor, stations, envelopes](../screenshots/floor.png)
#
# **FLOOR — conveyor, stations, envelopes** (`docs/screenshots/floor.png`)
#
# ![Pilot run — four envelopes in motion](../screenshots/pilot-floor.png)
#
# **PILOT RUN — envelopes in motion** (`docs/screenshots/pilot-floor.png`)
#
# ![INSPECTOR — spans, generations, judge scores](../screenshots/inspector.png)
#
# **INSPECTOR — spans, generations, judge scores** (`docs/screenshots/inspector.png`)
#
# ![REVIEW — Approve / Reject / Requeue + RECONSIDER](../screenshots/review.png)
#
# **REVIEW — Approve / Reject / Requeue + RECONSIDER** (`docs/screenshots/review.png`)
#
# ![SESSIONS — Langfuse matters](../screenshots/sessions.png)
#
# **SESSIONS — Langfuse matters** (`docs/screenshots/sessions.png`)
#
# ![HISTORY — recent runs + REPLAY](../screenshots/history.png)
#
# **HISTORY — recent runs + REPLAY** (`docs/screenshots/history.png`)
#
# ![METRICS — cost, tokens, verdict mix](../screenshots/metrics.png)
#
# **METRICS — cost, tokens, verdict mix** (`docs/screenshots/metrics.png`)
#
# ![CONSOLE — live log + DEBUG toggle](../screenshots/console.png)
#
# **CONSOLE — live log + DEBUG toggle** (`docs/screenshots/console.png`)

# %% [markdown]
# ## Hosted Observatory (`/live`, `mailroom-hosted`)
#
# Public modern desk. Same traces, different surface — not GitHub Pages.

# %% [markdown]
# ![Pipeline trays](../screenshots/observatory-pipeline.png)
#
# **Pipeline trays** (`docs/screenshots/observatory-pipeline.png`)
#
# ![Review resolve forms](../screenshots/observatory-review.png)
#
# **Review resolve forms** (`docs/screenshots/observatory-review.png`)
#
# ![History + Replay](../screenshots/observatory-history.png)
#
# **History + Replay** (`docs/screenshots/observatory-history.png`)
#
# ![Matters (Langfuse sessions)](../screenshots/observatory-matters.png)
#
# **Matters (Langfuse sessions)** (`docs/screenshots/observatory-matters.png`)
#
# ![Metrics](../screenshots/observatory-metrics.png)
#
# **Metrics** (`docs/screenshots/observatory-metrics.png`)
#
# ![Debug desk (`GET /api/debug/bundle`)](../screenshots/observatory-debug.png)
#
# **Debug desk (`GET /api/debug/bundle`)** (`docs/screenshots/observatory-debug.png`)

# %% [markdown]
# ## TUI (`mailroom-tui`)
#
# Keys: `[f]loor` `[r]eview` `[s]essions` `[m]etrics` `[i]nspect` `[` `]` `[d]ebug` `[q]uit`.
# Re-render SVGs/PNGs with `MAILROOM_API_URL=http://127.0.0.1:8001 python scripts/render_tui_shots.py`.

# %% [markdown]
# ![Floor — per-doc table + live log](../screenshots/tui-console.png)
#
# **Floor — per-doc table + live log** (`docs/screenshots/tui-console.png`)
#
# ![Review siding](../screenshots/tui-review.png)
#
# **Review siding** (`docs/screenshots/tui-review.png`)
#
# ![Sessions / matters](../screenshots/tui-sessions.png)
#
# **Sessions / matters** (`docs/screenshots/tui-sessions.png`)
#
# ![Metrics](../screenshots/tui-metrics.png)
#
# **Metrics** (`docs/screenshots/tui-metrics.png`)

# %% [markdown]
# ## Seed demo traces (into Langfuse)
#
# Demo runs are written **into** Langfuse (`env demo`). The visualizer still
# reads Langfuse only.
#
# ```bash
# python scripts/seed_demo.py
# python scripts/seed_demo.py --list-scenarios
# python scripts/seed_demo.py --check --check-api
# ```
#
# The pixel `D` key does not fabricate envelopes on a live floor (`?demo=1` only,
# and only when the source is down).

# %%
from pathlib import Path

root = Path.cwd()
if (root / "docs" / "screenshots").is_dir():
    shots = root / "docs" / "screenshots"
    demos = root / "docs" / "demos"
elif (root / "screenshots").is_dir():
    shots = root / "screenshots"
    demos = root
else:
    raise SystemExit(f"cannot find screenshots from {root}")

pngs = sorted(p.name for p in shots.glob("*.png"))
video = demos / "tui-server-observatory-desk-walkthrough.mp4"
print(f"{len(pngs)} stills in {shots}")
print("video", "OK" if video.exists() else "MISSING", video.name, video.stat().st_size if video.exists() else 0)
for name in pngs:
    print(" ", name)
assert video.exists(), "walkthrough mp4 missing from docs/demos/"
assert len(pngs) >= 17, pngs
